# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/Users/bhaskaradhikari/freelance/data/external/geo_insights_df')

# %%
df
# Out:
#      Event Date  User Pseudo ID      City        Country
# 0      20240123    1.803115e+09  Columbia  United States
# 1      20240123    1.370019e+09   Seattle  United States
# 2      20240123    2.091432e+09       NaN  United States
# 3      20240123    1.821760e+09   Cypress  United States
# 4      20240123    1.665243e+09    Lowell  United States
# ..          ...             ...       ...            ...
# 995    20240123    8.756038e+08   Midland  United States
# 996    20240123    8.756038e+08   Midland  United States
# 997    20240123    8.756038e+08   Midland  United States
# 998    20240123    8.756038e+08   Midland  United States
# 999    20240123    8.756038e+08   Midland  United States
#
# [1000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the visualization
sns.set(style="whitegrid")

# Visualization 1: Distribution of events by country
plt.figure(figsize=(10, 6))
country_counts = df['Country'].value_counts()
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
plt.title('Distribution of Events by Country')
plt.xlabel('Country')
plt.ylabel('Number of Events')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Visualization 2: Distribution of events by the top 10 cities
plt.figure(figsize=(10, 6))
city_counts = df['City'].value_counts().head(10)  # Top 10 cities
sns.barplot(x=city_counts.values, y=city_counts.index, palette="mako")
plt.title('Top 10 Cities by Number of Events')
plt.xlabel('Number of Events')
plt.ylabel('City')
plt.tight_layout()
plt.show()
